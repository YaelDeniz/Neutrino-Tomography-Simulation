# %%
import numpy as np
import matplotlib.pylab as plt
import csv
import matplotlib.pyplot as plt
import sys
import math
from matplotlib.colors import LogNorm 

np.float = float  # Redirect any 'np.float' usage to 'float'

def csv_to_matrix(file_path):
    # Load CSV data into a numpy matrix
    with open(file_path, 'r') as file:
        reader = csv.reader(file)
        data = np.array([list(map(float, row)) for row in reader])

    return data
    
## 1%
# Load the CSV file
csv_folder = "/home/dehy0499/NuOscillation-Tomography/Neutrino-Tomography-Simulation/SimulationResults/PreliminaryResults/ObsChi2/ObsChi2_-Height-rho1-pancake600_100_2-10_134-171_-55-55_2024-11-25/"
csv_file = csv_folder + "ObsChi2_cth_-Height-rho1-pancake600_100nu1_Obs30-100-30Int60-100-60.csv"  # Replace with your file path



chi2h1 = csv_to_matrix(csv_file)

h= chi2h1[:,2]
ne10_1 = chi2h1[:,3]
ne20_1 = 2*chi2h1[:,3]
ne40_1 = 4*chi2h1[:,3]


  
plt.plot(h, ne10_1, color = 'r', linestyle = '-', 
         marker = 'o') 
plt.plot(h, ne20_1, color = 'r', linestyle = ':', 
         marker = 'o') 
plt.plot(h, ne40_1, color = 'r', linestyle = '-.', 
         marker = 'o') 


## 2%
# Load the CSV file
csv_folder = "/home/dehy0499/NuOscillation-Tomography/Neutrino-Tomography-Simulation/SimulationResults/PreliminaryResults/ObsChi2/ObsChi2_-Height-rho2pancake600_100_2-10_134-171_-55-55_2024-11-25/"
csv_file = csv_folder + "ObsChi2_cth_-Height-rho2pancake600_100nu1_Obs30-100-30Int60-100-60.csv"  # Replace with your file path

chi2h = csv_to_matrix(csv_file)

h= chi2h[:,1]
ne10 = chi2h[:,2]
ne20 = 2*chi2h[:,2]
ne40 = 4*chi2h[:,2]


  
plt.plot(h, ne10, color = 'k', linestyle = '-', 
         marker = 'o') 
plt.plot(h, ne20, color = 'k', linestyle = ':', 
         marker = 'o') 
plt.plot(h, ne40, color = 'k', linestyle = '-.', 
         marker = 'o') 


## 3%
# Load the CSV file
csv_folder = "/home/dehy0499/NuOscillation-Tomography/Neutrino-Tomography-Simulation/SimulationResults/PreliminaryResults/ObsChi2/ObsChi2_-Height-rho3-pancake600_100_2-10_134-171_-55-55_2024-11-25/"
csv_file = csv_folder + "ObsChi2_cth_-Height-rho3-pancake600_100nu1_Obs30-100-30Int60-100-60.csv"  # Replace with your file path



chi2h3 = csv_to_matrix(csv_file)

h= chi2h3[:,1]
ne10_3 = chi2h3[:,2]
ne20_3 = 2*chi2h3[:,2]
ne40_3 = 4*chi2h3[:,2]


  
plt.plot(h, ne10_3, color = 'b', linestyle = '-', 
         marker = 'o') 
plt.plot(h, ne20_3, color = 'b', linestyle = ':', 
         marker = 'o') 
plt.plot(h, ne40_3, color = 'b', linestyle = '-.', 
         marker = 'o') 
  
plt.xticks(rotation = 25) 
plt.xlabel(r'$h_{LLVP}[km]$') 
plt.ylabel(r'$\Delta \chi^2$') 
plt.title(r'Observed sensitivity to $h_{LLVP}$ $[\Delta\rho/\rho: 2\%]$', fontsize = 15) 
plt.grid() 
plt.legend(['100 Mton-year','200 Mton-year','400 Mton-year']) 
plt.show()

# %%
np.float = float  # Redirect any 'np.float' usage to 'float'

def csv_to_matrix(file_path):
    # Load CSV data into a numpy matrix
    with open(file_path, 'r') as file:
        reader = csv.reader(file)
        data = np.array([list(map(float, row)) for row in reader])

    return data
    
## 1%
plt.plot(h, ne10_1, color = 'r', linestyle = '-', 
         marker = 'o') 
## 2%
plt.plot(h, ne10, color = 'k', linestyle = '-', 
         marker = 'o') 



## 3%
plt.plot(h, ne10_3, color = 'b', linestyle = '-', 
         marker = 'o') 
  
plt.xticks(rotation = 25) 
plt.xlabel(r'$h_{LLVP}[km]$') 
plt.ylabel(r'$\Delta \chi^2$') 
plt.title(r'Observed sensitivity to $h_{LLVP}$ $[\Delta\rho/\rho: 2\%]$', fontsize = 15) 
plt.grid() 
plt.legend([r'$\Delta\rho/\rho: 1\%$', r'$\Delta\rho/\rho: 2\%$', r'$\Delta\rho/\rho: 3\%$']) 
plt.show()

# %%
import numpy as np
import matplotlib.pylab as plt
import csv
import matplotlib.pyplot as plt
import sys
import math
from matplotlib.colors import LogNorm 

np.float = float  # Redirect any 'np.float' usage to 'float'

def csv_to_matrix(file_path):
    # Load CSV data into a numpy matrix
    with open(file_path, 'r') as file:
        reader = csv.reader(file)
        data = np.array([list(map(float, row)) for row in reader])

    return data


# Binning in th
# Load the CSV file
csv_folderth = "/home/dehy0499/NuOscillation-Tomography/Neutrino-Tomography-Simulation/SimulationResults/PreliminaryResults/ObsChi2/ObsChi2_-density-th-cake1000_100_2-10_128-171_-55-55_2024-11-26/"
csv_filethmu = csv_folderth + "ObsChi2_th_-density-th-cake1000_100nu1_Obs30-100-30Int60-100-60.csv"  # Replace with your file path
csv_filethe = csv_folderth + "ObsChi2_th_-density-th-cake1000_100nu0_Obs30-100-30Int60-100-60.csv"  # Replace with your file path

Chi2thmu = csv_to_matrix(csv_filethmu)
Chi2the = csv_to_matrix(csv_filethe)

ne = Chi2thmu[:,1]
chi2th = Chi2thmu[:,3] + Chi2the[:,3]

#Binning in cth
csv_foldercth = "/home/dehy0499/NuOscillation-Tomography/Neutrino-Tomography-Simulation/SimulationResults/PreliminaryResults/ObsChi2/ObsChi2_-density-cth-cake1000_100_2-10_128-171_-55-55_2024-11-25/"
csv_filecthmu = csv_foldercth + "ObsChi2_cth_-density-cth-pancake1000_100nu1_Obs30-100-30Int60-100-60.csv"  # Replace with your file path
csv_filecthe = csv_foldercth + "ObsChi2_cth_-density-cth-cake1000_100nu0_Obs30-100-30Int60-100-60.csv"  # Replace with your file path

Chi2cthmu = csv_to_matrix(csv_filecthmu)
Chi2cthe = csv_to_matrix(csv_filecthe)


ne = Chi2cthmu[:,1]
chi2cth = Chi2cthmu[:,3] + Chi2cthe[:,3]




plt.plot(ne, chi2cth, color = 'r', linestyle = '-', 
         marker = 'o') 
#plt.plot(ne, 2*chi2cth, color = 'r', linestyle = '--',marker = 'o') 
#plt.plot(ne, 4*chi2cth, color = 'r', linestyle = ':',marker = 'o') 

plt.plot(ne, chi2th, color = 'b', linestyle = '-', 
         marker = 'o') 
#plt.plot(ne, 2*chi2th, color = 'b', linestyle = '--', marker = 'o') 
#plt.plot(ne, 4*chi2th, color = 'b', linestyle = ':',  marker = 'o') 


  
plt.xticks(rotation = 25) 
plt.xlabel(r'$n_e$') 
plt.ylabel(r'$\Delta \chi^2$') 
plt.title(r'Observed sensitivity to $\Delta\rho/\rho$ [Layered LLVP; $h_{LLVP}=$1000 km ]', fontsize = 15) 
plt.grid() 
plt.legend(['Binning in cth','Binning in th','400 Mton-year']) 
plt.show()
